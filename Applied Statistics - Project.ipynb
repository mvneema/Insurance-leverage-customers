# %% [markdown]
# # Steps and Tasks

# %% [markdown]
# ## 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns     # library for advance visualization

# %% [markdown]
# ## 2. Read the data as a data frame

# %%
insur_data = pd.read_csv('insurance.csv')
insur_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## 3.Perform basic EDA which should include the following and print out your insights
# ## at every step.

# %% [markdown]
# ### a. Shape of the data

# %%
insur_data.shape
# Out:
# (1338, 7)

# %% [markdown]
# **There are 1338 Observations / Rows and 7 Attributes / Columns.**

# %% [markdown]
# ### b. Data type of each attribute

# %%
insur_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# sex         1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# ### c. Checking the presence of missing values

# %%
# number of missing values (only the ones recognised as missing values) in each of the attributes
pd.DataFrame( insur_data.isnull().sum(), columns= ['Number of missing values'])
# Out:
#           Number of missing values
# age                              0
# sex                              0
# bmi                              0
# children                         0
# smoker                           0
# region                           0
# charges                          0

# %% [markdown]
# * There are no missing values in any of the fields for insur_data dataframe

# %% [markdown]
# ### d. 5 point summary of numerical attributes

# %%
insur_data.describe() # the output results provide the five number summary of the data.
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Additionally we can see the 5 point summary individually
# Print the mean of each attribute. 
print("Insurance Data:",insur_data.mean())
# Out:
# Insurance Data: age            39.207025
# bmi            30.663397
# children        1.094918
# charges     13270.422265
# dtype: float64

# %%
# Print the mode of the attribute. 
print(insur_data.mode())
# Out:
#    age   sex   bmi  children smoker     region    charges
# 0   18  male  32.3         0     no  southeast  1639.5631

# %%
# Print the median values of the data.
print("Insurance Data:",insur_data.median()) 
# Observe that the values of mean and median are almost the same for bmi
# Out:
# Insurance Data: age           39.000
# bmi           30.400
# children       1.000
# charges     9382.033
# dtype: float64

# %%
# Prints the value below which 25% of the data lies
print("Insur_data_quantile(25%):",insur_data.quantile(q=0.25))
# Out:
# Insur_data_quantile(25%): age           27.00000
# bmi           26.29625
# children       0.00000
# charges     4740.28715
# Name: 0.25, dtype: float64

# %%
# Prints the value below which 50% of the data lies
print("Insur_data_quantile(50%):",insur_data.quantile(q=0.50))
# Out:
# Insur_data_quantile(50%): age           39.000
# bmi           30.400
# children       1.000
# charges     9382.033
# Name: 0.5, dtype: float64

# %%
# Prints the value below which 75% of the data lies
print("Insur_data_quantile(75%):",insur_data.quantile(q=0.75))
# Out:
# Insur_data_quantile(75%): age            51.000000
# bmi            34.693750
# children        2.000000
# charges     16639.912515
# Name: 0.75, dtype: float64

# %% [markdown]
# ### e. Distribution of ‘bmi’, ‘age’ and ‘charges’ columns

# %% [markdown]
# #### Histogram of bmi

# %%
mean=insur_data['bmi'].mean()
median=insur_data['bmi'].median()
mode=insur_data['bmi'].mode()

print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])

plt.figure(figsize=(10,5)) # set the figure size
plt.hist(insur_data['bmi'],bins=100,color='lightblue') #Plot the histogram

plt.axvline(mean,color='green',label='Mean')     
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='red',label='Mode')

plt.xlabel('bmi')         # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  30.663396860986538
# Median:  30.4
# Mode:  32.3

# %% [markdown]
# * the distribution for bmi is right skewed.

# %% [markdown]
# #### Histogram for age

# %%
mean=insur_data['age'].mean()
median=insur_data['age'].median()
mode=insur_data['age'].mode()

print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])

plt.figure(figsize=(10,5)) # set the figure size
plt.hist(insur_data['age'],bins=100,color='lightblue') #Plot the histogram

plt.axvline(mean,color='green',label='Mean')     
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='red',label='Mode')

plt.xlabel('age')         # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  39.20702541106129
# Median:  39.0
# Mode:  18

# %% [markdown]
# * the distribution for age is right skewed.

# %% [markdown]
# #### Histogram for 'charges'

# %%
mean=insur_data['charges'].mean()
median=insur_data['charges'].median()
mode=insur_data['charges'].mode()

print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])

plt.figure(figsize=(10,5)) # set the figure size
plt.hist(insur_data['charges'],bins=100,color='lightblue') #Plot the histogram

plt.axvline(mean,color='green',label='Mean')     
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='red',label='Mode')

plt.xlabel('charges')     # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  13270.422265141257
# Median:  9382.033
# Mode:  1639.5631

# %% [markdown]
# * the distribution for charges is right skewed.

# %% [markdown]
# ### f. Measure of skewness of ‘bmi’, ‘age’ and ‘charges’ columns

# %%
insur_data.skew()
# Out:
# age         0.055673
# bmi         0.284047
# children    0.938380
# charges     1.515880
# dtype: float64

# %% [markdown]
# * Measure of skweness for 'bmi' is 0.284047, 'age' is 0.055673, 'charges' is 1.515880

# %% [markdown]
# #### Distribution to check measure of skewness for 'bmi'

# %%
#convert pandas DataFrame object to numpy array and sort
h = np.asarray(insur_data['bmi'])
h = sorted(h)
 
#use the scipy stats module to fit a normal distirbution with same mean and standard deviation
fit = stats.norm.pdf(h, np.mean(h), np.std(h)) 
 
#plot both series on the histogram
plt.plot(h,fit,'-',linewidth = 2,label="Normal distribution with same mean and var")
plt.hist(h,normed=True,bins = 100,label="Actual distribution")      
plt.legend()
plt.show()
# Out:
# C:\Users\Neema MV\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   if sys.path[0] == '':

# %% [markdown]
# * We can see int the above graph that it is positive skewed with skewness score 0.284047

# %% [markdown]
# #### Distribution to check measure of skewness for 'age'

# %%
i = np.asarray(insur_data['age'])
i = sorted(i)
 
#use the scipy stats module to fit a normal distirbution with same mean and standard deviation
fit = stats.norm.pdf(i, np.mean(i), np.std(i)) 
 
#plot both series on the histogram
plt.plot(i,fit,'-',linewidth = 2,label="Normal distribution with same mean and var")
plt.hist(i,normed=True,bins = 100,label="Actual distribution")      
plt.legend()
plt.show()
# Out:
# C:\Users\Neema MV\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   if __name__ == '__main__':

# %% [markdown]
# * We can see int the above graph that it is close to zero skewness with the skewness score 0.055673

# %% [markdown]
# #### Distribution to check measure of skewness for 'charges'

# %%
j = np.asarray(insur_data['charges'])
j = sorted(h)
 
#use the scipy stats module to fit a normal distirbution with same mean and standard deviation
fit = stats.norm.pdf(j, np.mean(j), np.std(j)) 
 
#plot both series on the histogram
plt.plot(j,fit,'-',linewidth = 2,label="Normal distribution with same mean and var")
plt.hist(j,normed=True,bins = 100,label="Actual distribution")      
plt.legend()
plt.show()
# Out:
# C:\Users\Neema MV\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   if __name__ == '__main__':

# %% [markdown]
# * We can see int the above graph that it is positive skewed with skewness score 1.515880

# %% [markdown]
# ### g. Checking the presence of outliers in ‘bmi’, ‘age’ and ‘charges columns

# %% [markdown]
# #### Outliers in 'bmi'

# %%
sns.boxplot(x=insur_data['bmi'])   # box plot

# %% [markdown]
# **Note:** Above plot shows several points after 45, these are outliers as they are not included in the box of other observation i.e no where near the quartiles.

# %% [markdown]
# #### Outliers in 'age'

# %%
sns.boxplot(x=insur_data['age'])   # box plot

# %% [markdown]
# **Note:** Above plot does not show any points after the quartile range. Hence no outliers.

# %% [markdown]
# #### Outliers in 'charges'

# %%
sns.boxplot(x=insur_data['charges'])   # box plot

# %% [markdown]
# **Note:** Above plot show many points after 35000 that are not included in the box of other observations.

# %% [markdown]
# #### h. Distribution of categorical columns (include children)

# %%
# Scatter plot between region and charges
sns.barplot(x="region", y="charges",  data=insur_data);

# %% [markdown]
# * Charges are highest in southeast region

# %%
# Box plot to check charges by region and sex
sns.boxplot(x="region", y="charges", hue = "sex", data=insur_data);

# %% [markdown]
# * Charges are higher for male & female in southeast region

# %%
# Box plot to check charges by region and smoker
sns.boxplot(x="region", y="charges", hue = "smoker", data=insur_data);

# %% [markdown]
# * Charges are higher for smokers in all the regions when compared to the non smokers

# %%
# Box plot to check charges by sex and smoker
sns.barplot(x="sex", y="charges", hue = "smoker",data=insur_data);

# %% [markdown]
# * Charges are higher for male & female smokers when compared to the non smokers

# %%
# Countplot to check the charges with respect to children
sns.countplot(x="children",data=insur_data);

# %% [markdown]
# * People with no children have high insurance charges. while it is the least for people with 5 children

# %% [markdown]
# #### i. Pair plot that includes all the columns of the data frame

# %%
sns.pairplot(insur_data, kind = "reg") 
plt.suptitle('Pair Plot of Insurance data', 
             size = 20);# plots scatter plots for every pair of attributes and histograms along the diagonal
plt.show()

# %% [markdown]
# * Age has positive correlation trend with charges.
# * bmi has a similar positive trend with respect to charges.

# %%
sns.pairplot(insur_data, hue = "sex") 
plt.suptitle('Pair Plot of Insurance data by sex', 
             size = 20);# plots scatter plots for every pair of attributes and histograms along the diagonal
plt.show()

# %% [markdown]
# * Age has positive correlation trend with charges wherein there are intensively shown by Male and bit dispersed for females.
# * bmi has a similar positive trend with respect to charges by sex.

# %%
sns.pairplot(insur_data, hue = "region") 
plt.suptitle('Pair Plot of Insurance data by region', 
             size = 20);# plots scatter plots for every pair of attributes and histograms along the diagonal
plt.show()

# %% [markdown]
# * Age has positive correlation trend with charges wherein northeast has bit more linear trend when compared to other regions.
# * bmi has a dispersed trend with respect to charges by region.

# %%
# Heat map for checking the correlation
fig,ax = plt.subplots(figsize=(10, 10))   
sns.heatmap(insur_data.corr(), ax=ax, annot=True, linewidths=0.05, fmt= '.2f',cmap="magma") # the color intensity is based on 
plt.show()

# %% [markdown]
# * Similar positive correlation for bmi and age with respect to charges, the rest of the attributes do not show much correlation

# %% [markdown]
# ### Answer the following questions with statistical evidence

# %% [markdown]
# #### a. Do charges of people who smoke differ significantly from the people who don't?

# %%
# array of values for Charges & smoker
smoke_charge = np.array(insur_data[['charges','smoker']])

# %%
# Data split for group 1 (smokers) & group 2 (non smokers)
group1 = smoke_charge[:, 1] == "no"
group1 = smoke_charge[group1][:, 0]
group2 = smoke_charge[:, 1] == "yes"
group2 = smoke_charge[group2][:, 0]

# %%
# load the necessary libraries
from scipy.stats import ttest_1samp, ttest_ind, mannwhitneyu, levene, shapiro
from statsmodels.stats.power import ttest_power

# %%
# two-sample t-test
# null hypothesis: the two groups have the same mean
# this test assumes the two groups have the same variance...

t_statistic, p_value = ttest_ind(group1, group2)
print(t_statistic, p_value)
# Out:
# -46.664921172723744 8.271435842174398e-283

# %%
# p_value < 0.05 => alternative hypothesis:
# they don't have the same mean at the 5% significance level
print ("two-sample t-test p-value=", p_value)
# Out:
# two-sample t-test p-value= 8.271435842174398e-283

# %% [markdown]
# * Yes charges of people who smoke differ significantly from the people who do not smoke

# %% [markdown]
# #### b. Does bmi of males differ significantly from that of females?

# %%
# array of values for bmi and sex from insur_data
bmi_sex = np.array(insur_data[['bmi','sex']])

# %%
# data split between group1 ( bmi for male) and group2 (bmi for female)
group1 = bmi_sex[:, 1] == "male"
group1 = bmi_sex[group1][:, 0]
group2 = bmi_sex[:, 1] == "female"
group2 = bmi_sex[group2][:, 0]

# %%
# two-sample t-test
# null hypothesis: the two groups have the same mean
# this test assumes the two groups have the same variance...
t_statistic, p_value = ttest_ind(group1, group2)
print(t_statistic, p_value)
# Out:
# 1.6967526357520633 0.08997637178987965

# %%
# p_value > 0.05 => null hypothesis:
# they have the same mean at the 5% significance level
print ("two-sample t-test p-value=", p_value)
# Out:
# two-sample t-test p-value= 0.08997637178987965

# %% [markdown]
# * No, as the p-value is greater than 0.05 they have same mean at 5% significance level and bmi of males do not differ from that of females

# %% [markdown]
# #### c. Is the proportion of smokers significantly different in different genders?

# %% [markdown]
# * 'sex' and 'smoker' are two categorical variables
# * We want to check if the proportion of smokers in the female population is significantly less than it is in the male population
#
# #### Ho = The proportions are equal
# #### Ha = The two proportions are not equal

# %%
 # number of female smokers
female_smokers = insur_data[insur_data['sex'] == 'female'].smoker.value_counts()[1] 
# number of male smokers
male_smokers = insur_data[insur_data['sex'] == 'male'].smoker.value_counts()[1] 
# number of females in the data
n_females = insur_data.sex.value_counts()[1] 
#number of males in the data
n_males = insur_data.sex.value_counts()[0]

# %%
print([female_smokers, male_smokers] , [n_females, n_males])
print(f' Proportion of smokers in females, males = {round(115/662,2)}%, {round(159/676,2)}% respectively')
# Out:
# [115, 159] [662, 676]
#  Proportion of smokers in females, males = 0.17%, 0.24% respectively

# %%
from statsmodels.stats.proportion import proportions_ztest

stat, pval = proportions_ztest([female_smokers, male_smokers] , [n_females, n_males])

if pval < 0.05:
    print(f'With a p-value of {round(pval,4)} the difference is significant. Hence, We reject the null|')
else:
    print(f'With a p-value of {round(pval,4)} the difference is not significant. Hence, We fail to reject the null|')
# Out:
# With a p-value of 0.0053 the difference is significant. Hence, We reject the null|

# %% [markdown]
# #### d. Is the distribution of bmi across women with no children, one child and two children, the same?

# %%
insur_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# data for female with zero children
zero_children_data = insur_data[insur_data['children']==0]
female_w_zero = zero_children_data[zero_children_data['sex']=='female']
df1 = female_w_zero[['bmi','children']]
# data for female with one children
one_children_data = insur_data[insur_data['children']==1]
female_w_one = one_children_data[one_children_data['sex']=='female']
df2 = female_w_one[['bmi','children']]
# data for female with two children
two_children_data = insur_data[insur_data['children']==2]
female_w_two = two_children_data[two_children_data['sex']=='female']
df3 = female_w_two[['bmi','children']]

# %%
female_bmi_by_children = pd.DataFrame()
female_bmi_by_children = female_bmi_by_children.append(df1) 
female_bmi_by_children = female_bmi_by_children.append(df2) 
female_bmi_by_children = female_bmi_by_children.append(df3)

# %% [markdown]
# ### Let us explore the data graphically

# %%
sns.boxplot(x = "children", y = "bmi", data = female_bmi_by_children)
plt.title('BMI for females by children 0,1,2')
plt.show()

# %% [markdown]
# #### The boxplots show almost similar shapes, location and spreads and there is no outlier.

# %% [markdown]
# ### Step 1: State the null and alternative hypothesis:
#
# * $H_0$: $\mu1$ = $\mu2$ = $\mu3$
# * $H_A$: At least one $\mu$ differs
#
# Here $\mu1$, $\mu2$ and $\mu3$ are the mean pressure applied to the driver's head during crash test by Compact car, Midsize car and Full size car respectively.

# %% [markdown]
# ### Step 2: Decide the significance level

# %% [markdown]
# Here we select α = 0.05

# %% [markdown]
# ### Step 3: Identify the test statistic

# %% [markdown]
# Here we have three groups. Analysis of variance can determine whether the means of three or more groups are different. ANOVA uses F-tests to statistically test the equality of means.

# %% [markdown]
# ### Step 4: Calculate p value using ANOVA table

# %% [markdown]
# * statsmodels.formula.api.ols creates a model from a formula and dataframe
# * statsmodels.api.sm.stats.anova_lm gives an Anova table for one or more fitted linear models

# %%
import statsmodels.api         as     sm
from   statsmodels.formula.api import ols
 
mod = ols('bmi ~ children', data = female_bmi_by_children).fit()
aov_table = sm.stats.anova_lm(mod, typ=2)
print(aov_table)
# Out:
#                 sum_sq     df         F   PR(>F)
# children      2.512982    1.0  0.068411  0.79376
# Residual  20717.738725  564.0       NaN      NaN

# %% [markdown]
# In this example, p value is 0.79376 and it is greater than our chosen level of signifance at 5%
#
# So the statistical decision is to not reject the null hypothesis at 5% level of significance.
#
# ### So there is  no evidence  to reject the null hypothesis that at least one bmi of childrens (0,1,2) is different from others .
